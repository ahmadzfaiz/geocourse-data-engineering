# %%
import geopandas as gpd
import xmltodict
from shapely import wkt, Point
import xml.etree.ElementTree as ET

# %% [markdown]
# ## Extract WFS GetCapabilities information

# %% [markdown]
# Reference: https://www.ogc.org/publications/standard/wfs/

# %%
file_path = "../../extract/output/wfs_get_capabilities.xml"

# %%
with open(file_path, "r") as f:
  data = xmltodict.parse(f.read())

# %%
data
# Out:
# {'wfs:WFS_Capabilities': {'@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   '@xmlns': 'http://www.opengis.net/wfs/2.0',
#   '@xmlns:wfs': 'http://www.opengis.net/wfs/2.0',
#   '@xmlns:ows': 'http://www.opengis.net/ows/1.1',
#   '@xmlns:gml': 'http://www.opengis.net/gml/3.2',
#   '@xmlns:fes': 'http://www.opengis.net/fes/2.0',
#   '@xmlns:xlink': 'http://www.w3.org/1999/xlink',
#   '@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#   '@xmlns:xml': 'http://www.w3.org/XML/1998/namespace',
#   '@xmlns:OPDJATENG': 'OPDJATENG',
#   '@xmlns:DishanpanJawaTengah': 'DishanpanJawaTengah',
#   '@xmlns:DisdikbudJawaTengah': 'DisdikbudJawaTengah',
#   '@xmlns:Satpolpp': 'Satpolpp',
#   '@xmlns:BappedaJawaTengah': 'BappedaJawaTengah',
#   '@xmlns:DinaskpJawaTengah': 'DinaskpJawaTengah',
#   '@xmlns:DisporaparJawaTengah': 'DisporaparJawaTengah',
#   '@xmlns:DistanbunJawaTengah': 'DistanbunJawaTengah',
#   '@xmlns:Dpusdataru': 'Dpusdataru',
#   '@xmlns:BKDJawaTengah': 'BKDJawaTengah',
#   '@xmlns:DinasesdmJawaTengah': 'DinasesdmJawaTengah',
#   '@xmlns:DpubmckJawaTengah': 'DpubmckJawaTengah',
#   '@xmlns:DinaslhkJawaTengah': 'DinaslhkJawaTengah',
#   '@xmlns:BiroPemotdaksJawaTengah': 'BiroPemotdaksJawaTengah',
#   '@xmlns:DishubJawaTengah': 'DishubJawaTengah',
#   '@xmlns:DisperindagJawaTengah': 'DisperindagJawaTengah',
#   '@xmlns:DisnakertransJawaTengah': 'DisnakertransJawaTengah',
#   '@xmlns:ADMIN': 'ADMIN',
#   '@xmlns:DisperakimJawaTengah': 'DisperakimJawaTengah',
#   '@xmlns:DinkopukmJawaTengah': 'DinkopukmJawaTengah',
#   '@xmlns:DiskominfoJawaTengah': 'DiskominfoJawaTengah',
#   '@xmlns:DinkesJawaTengah': 'DinkesJawaTengah',
#   '@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#   '@xmlns:Kabkota': 'Kabkota',
#   '@xmlns:Kesbangpol': 'Kesbangpol',
#   '@xmlns:KUGI': 'KUGI',
#   '@xmlns:Walidatadaerah': 'Walidatadaerah',
#   '@xmlns:DinsosJawaTengah': 'DinsosJawaTengah',
#   '@xmlns:DisnakeswanJawaTengah': 'DisnakeswanJawaTengah',
#   '@xmlns:BPBDJawaTengah': 'BPBDJawaTengah',
#   '@xmlns:BapendaJawaTengah': 'BapendaJawaTengah',
#   '@xmlns:BPKADJawaTengah': 'BPKADJawaTengah',
#   '@xmlns:geodata': 'geodata',
#   '@xmlns:DpmptspJawaTengah': 'DpmptspJawaTengah',
#   '@version': '2.0.0',
#   '@xsi:schemaLocation': 'http://www.opengis.net/wfs/2.0 http://geoportal.jatengprov.go.id/geoserver/schemas/wfs/2.0/wfs.xsd',
#   '@updateSequence': '7956',
#   'ows:ServiceIdentification': {'ows:Title': 'GeoServer Web Feature Service',
#    'ows:Abstract': 'This is the reference implementation of WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.',
#    'ows:Keywords': {'ows:Keyword': ['WFS', 'WMS', 'GEOSERVER']},
#    'ows:ServiceType': 'WFS',
#    'ows:ServiceTypeVersion': '2.0.0',
#    'ows:Fees': 'NONE',
#    'ows:AccessConstraints': 'NONE'},
#   'ows:ServiceProvider': {'ows:ProviderName': 'Provinsi Jawa Tengah',
#    'ows:ServiceContact': {'ows:IndividualName': '(024) 8319140',
#     'ows:PositionName': 'Jl. Menteri Supeno 1 / 2 , Semarang 50243',
#     'ows:ContactInfo': {'ows:Phone': {'ows:Voice': None,
#       'ows:Facsimile': '(024) 8443916'},
#      'ows:Address': {'ows:DeliveryPoint': None,
#       'ows:City': 'Semarang',
#       'ows:AdministrativeArea': 'Jawa Tengah',
#       'ows:PostalCode': '50243',
#       'ows:Country': 'Indonesia',
#       'ows:ElectronicMailAddress': 'diskominfo@jatengprov.go.id'}}}},
#   'ows:OperationsMetadata': {'ows:Operation': [{'@name': 'GetCapabilities',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': [{'@name': 'AcceptVersions',
#        'ows:AllowedValues': {'ows:Value': ['1.0.0', '1.1.0', '2.0.0']}},
#       {'@name': 'AcceptFormats',
#        'ows:AllowedValues': {'ows:Value': 'text/xml'}}]},
#     {'@name': 'DescribeFeatureType',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': {'@name': 'outputFormat',
#       'ows:AllowedValues': {'ows:Value': 'text/xml; subtype=gml/3.2'}}},
#     {'@name': 'GetFeature',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': [{'@name': 'resultType',
#        'ows:AllowedValues': {'ows:Value': ['results', 'hits']}},
#       {'@name': 'outputFormat',
#        'ows:AllowedValues': {'ows:Value': ['text/xml; subtype=gml/3.2',
#          'GML2',
#          'KML',
#          'SHAPE-ZIP',
#          'application/gml+xml; version=3.2',
#          'application/json',
#          'application/vnd.google-earth.kml xml',
#          'application/vnd.google-earth.kml+xml',
#          'csv',
#          'gml3',
#          'gml32',
#          'json',
#          'text/xml; subtype=gml/2.1.2',
#          'text/xml; subtype=gml/3.1.1']}}],
#      'ows:Constraint': [{'@name': 'PagingIsTransactionSafe',
#        'ows:NoValues': None,
#        'ows:DefaultValue': 'FALSE'},
#       {'@name': 'CountDefault',
#        'ows:NoValues': None,
#        'ows:DefaultValue': '1000000'}]},
#     {'@name': 'GetPropertyValue',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': {'@name': 'resolve',
#       'ows:AllowedValues': {'ows:Value': 'none'}}},
#     {'@name': 'ListStoredQueries',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}}},
#     {'@name': 'DescribeStoredQueries',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}}},
#     {'@name': 'CreateStoredQuery',
#      'ows:DCP': {'ows:HTTP': {'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}}},
#     {'@name': 'DropStoredQuery',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}}},
#     {'@name': 'LockFeature',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': {'@name': 'releaseAction',
#       'ows:AllowedValues': {'ows:Value': ['ALL', 'SOME']}}},
#     {'@name': 'GetFeatureWithLock',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': [{'@name': 'resultType',
#        'ows:AllowedValues': {'ows:Value': ['results', 'hits']}},
#       {'@name': 'outputFormat',
#        'ows:AllowedValues': {'ows:Value': ['text/xml; subtype=gml/3.2',
#          'GML2',
#          'KML',
#          'SHAPE-ZIP',
#          'application/gml+xml; version=3.2',
#          'application/json',
#          'application/vnd.google-earth.kml xml',
#          'application/vnd.google-earth.kml+xml',
#          'csv',
#          'gml3',
#          'gml32',
#          'json',
#          'text/xml; subtype=gml/2.1.2',
#          'text/xml; subtype=gml/3.1.1']}}],
#      'ows:Constraint': [{'@name': 'PagingIsTransactionSafe',
#        'ows:NoValues': None,
#        'ows:DefaultValue': 'FALSE'},
#       {'@name': 'CountDefault',
#        'ows:NoValues': None,
#        'ows:DefaultValue': '1000000'}]},
#     {'@name': 'Transaction',
#      'ows:DCP': {'ows:HTTP': {'ows:Get': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'},
#        'ows:Post': {'@xlink:href': 'http://geoportal.jatengprov.go.id/geoserver/wfs'}}},
#      'ows:Parameter': [{'@name': 'inputFormat',
#        'ows:AllowedValues': {'ows:Value': 'text/xml; subtype=gml/3.2'}},
#       {'@name': 'releaseAction',
#        'ows:AllowedValues': {'ows:Value': ['ALL', 'SOME']}}]}],
#    'ows:Constraint': [{'@name': 'ImplementsBasicWFS',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsTransactionalWFS',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsLockingWFS',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'KVPEncoding', 'ows:NoValues': None, 'ows:DefaultValue': 'TRUE'},
#     {'@name': 'XMLEncoding', 'ows:NoValues': None, 'ows:DefaultValue': 'TRUE'},
#     {'@name': 'SOAPEncoding',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsInheritance',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'FALSE'},
#     {'@name': 'ImplementsRemoteResolve',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'FALSE'},
#     {'@name': 'ImplementsResultPaging',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsStandardJoins',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsSpatialJoins',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsTemporalJoins',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'ImplementsFeatureVersioning',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'FALSE'},
#     {'@name': 'ManageStoredQueries',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'TRUE'},
#     {'@name': 'PagingIsTransactionSafe',
#      'ows:NoValues': None,
#      'ows:DefaultValue': 'FALSE'},
#     {'@name': 'QueryExpressions',
#      'ows:AllowedValues': {'ows:Value': ['wfs:Query', 'wfs:StoredQuery']}}]},
#   'FeatureTypeList': {'FeatureType': [{'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:adm_jateng_bts_desa_250k_330020200517094901',
#      'Title': 'ADM_JATENG_BTS_DESA_250K',
#      'Abstract': 'ADM_JATENG_BTS_DESA_250K',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'adm_jateng_bts_desa_250k_330020200517094901']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540176391602 -8.22111988067627',
#       'ows:UpperCorner': '111.707092285156 -6.37127590179443'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:adm_semarang_bts_rw_330020220720082500',
#      'Title': 'Adm_Semarang_Bts_RW_AR',
#      'Abstract': 'Batas Administrasi Rukun Warga (RW) di Kota Semarang',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'adm_semarang_bts_rw_330020220720082500']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '110.2672863 -7.1144639',
#       'ows:UpperCorner': '110.5088836 -6.9319917'}},
#     {'@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#      'Name': 'DispermasdesJawaTengah:air_minum_kemasan_jawa_tengah_330020201116102906',
#      'Title': 'Air_Minum_Kemasan_Jawa_Tengah',
#      'Abstract': 'Air Minum Kemasan Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'air_minum_kemasan_jawa_tengah_330020201116102906']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540176391602 -8.22111988067627',
#       'ows:UpperCorner': '111.707092285156 -6.37127590179443'}},
#     {'@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#      'Name': 'DispermasdesJawaTengah:air_minum_ledeng_jawa_tengah_330020201116103129',
#      'Title': 'Air_Minum_Ledeng_Jawa_Tengah',
#      'Abstract': 'Air Minum Ledeng Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'air_minum_ledeng_jawa_tengah_330020201116103129']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.55585483913 -8.21196175812861',
#       'ows:UpperCorner': '111.691411993269 -5.72569801255321'}},
#     {'@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#      'Name': 'DispermasdesJawaTengah:air_minum_sumber_lainnya_jawa_tengah_330020201116103303',
#      'Title': 'Air_Minum_Sumber_Lainnya_Jawa_Tengah',
#      'Abstract': 'Air Minum Sumber Lainnya Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'air_minum_sumber_lainnya_jawa_tengah_330020201116103303']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540176391602 -8.22111988067627',
#       'ows:UpperCorner': '111.707092285156 -6.37127590179443'}},
#     {'@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#      'Name': 'DispermasdesJawaTengah:air_minum_sumber_terlindungi_jawa_tengah_330020201116103538',
#      'Title': 'Air_Minum_Sumber_Terlindungi_Jawa_Tengah',
#      'Abstract': 'Air Minum Sumber Terlindungi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'air_minum_sumber_terlindungi_jawa_tengah_330020201116103538']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.55585483913 -8.21196175812861',
#       'ows:UpperCorner': '111.691411993269 -5.72569801255321'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:adm_jateng_bts_kabupaten_kota_250k_330020190617103125',
#      'Title': 'Batas Kabupaten Kota Jawa Tengah 250K',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'adm_jateng_bts_kabupaten_kota_250k_330020190617103125']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.555854839065 -8.21196175806421',
#       'ows:UpperCorner': '111.691411993135 -5.72569801277643'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:adm_jateng_bts_kecamatan_250k_330020190617103256',
#      'Title': 'Batas Kecamatan Jawa Tengah 250K',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'adm_jateng_bts_kecamatan_250k_330020190617103256']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.55585483913 -8.21196175812855',
#       'ows:UpperCorner': '111.691411993269 -5.72569801255309'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:budidaya_rumput_laut_jawa_tengah_2018_330020210104114146',
#      'Title': 'Budidaya_Rumput_Laut_jawa_Tengah_2018',
#      'Abstract': 'Potensi Lokasi Kesesuaian Budidaya Rumput Laut Provinsi Jawa Tengah Tahun 2018',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'budidaya_rumput_laut_jawa_tengah_2018_330020210104114146']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32646',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.61456949263851 -7.018573438781015',
#       'ows:UpperCorner': '111.87563301656925 -5.500666110463199'}},
#     {'@xmlns:DinasesdmJawaTengah': 'DinasesdmJawaTengah',
#      'Name': 'DinasesdmJawaTengah:cat_jateng_region_330020231213140345',
#      'Title': 'CAT_JATENG_region',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['cat_jateng_region_330020231213140345',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.550992 -8.249207',
#       'ows:UpperCorner': '111.939563 -6.407545'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:candi_di_jawa_tengah_330020220822074546',
#      'Title': 'Candi_di_Jawa_Tengah_PT',
#      'Abstract': 'Tempat Ibadah Candi di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'candi_di_jawa_tengah_330020220822074546']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::3857',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.90692414097157 -7.76104566382751',
#       'ows:UpperCorner': '110.50464613604936 -7.205043803252967'}},
#     {'@xmlns:DinasesdmJawaTengah': 'DinasesdmJawaTengah',
#      'Name': 'DinasesdmJawaTengah:cekungan_air_tanah_jawa_tengah_330020201112100857',
#      'Title': 'Cekungan_Air_Tanah_Jawa_Tengah',
#      'Abstract': 'Cekungan Air Tanah Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['cekungan_air_tanah_jawa_tengah_330020201112100857',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.543045043945 -8.22052097320557',
#       'ows:UpperCorner': '111.709411621094 -6.39672565460205'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:depo_bbm_330020190515113348',
#      'Title': 'DEPO_BBM_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'depo_bbm_330020190515113348']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.96337110811207 -7.78488583896718',
#       'ows:UpperCorner': '111.60408134956495 -6.710024906296904'}},
#     {'@xmlns:Dpusdataru': 'Dpusdataru',
#      'Name': 'Dpusdataru:danau_provinsi_jawa_tengah_330020200826142727',
#      'Title': 'Danau_Provinsi_Jawa_Tengah',
#      'Abstract': 'Danau Provinsi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['danau_provinsi_jawa_tengah_330020200826142727',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.78998057464455 -7.984417428291692',
#       'ows:UpperCorner': '111.6115463424496 -6.647224275325419'}},
#     {'@xmlns:DisporaparJawaTengah': 'DisporaparJawaTengah',
#      'Name': 'DisporaparJawaTengah:daya_tarik_wisata_pt_330020231227082506',
#      'Title': 'Daya_Tarik_Wisata_PT',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'daya_tarik_wisata_pt_330020231227082506']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.807762557313 -7.87853462126809',
#       'ows:UpperCorner': '111.411945689197 -5.84127516280239'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:fasilitas_kesehatan_vaksinasi_jawa_tengah_330020210426124814',
#      'Title': 'Fasilitas_Kesehatan_Vaksinasi_Jawa_Tengah',
#      'Abstract': 'Fasilitas nKesehatan Vaksinasi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'fasilitas_kesehatan_vaksinasi_jawa_tengah_330020210426124814']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.61208 -8.16279999999995',
#       'ows:UpperCorner': '111.67232768 -5.83822999999995'}},
#     {'@xmlns:DisporaparJawaTengah': 'DisporaparJawaTengah',
#      'Name': 'DisporaparJawaTengah:geospasial_deswita_pt_330020231227082250',
#      'Title': 'GEOSPASIAL_DESWITA_PT',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'geospasial_deswita_pt_330020231227082250']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '-7.86242365302139 108.827347397817',
#       'ows:UpperCorner': '-6.55499925461606 111.583467337464'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:kontur_330020190510095118',
#      'Title': 'Garis Kontur Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kontur_330020190510095118']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.27611284847853 -8.264526254691376',
#       'ows:UpperCorner': '111.86107433172143 -6.22633624263489'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:garispantaijawatengah_ln_25k_330020190515102758',
#      'Title': 'Garis_Pantai_Jawa_Tengah_LN_250K',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'garispantaijawatengah_ln_25k_330020190515102758']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.818977355957 -6.96198797225952',
#       'ows:UpperCorner': '111.480743408203 -5.71627759933472'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:geologi_jawa_tengah_330020210419095955',
#      'Title': 'Geologi_Jawa_Tengah',
#      'Abstract': 'Peta Geologi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'geologi_jawa_tengah_330020210419095955']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540176391602 -8.22352886199951',
#       'ows:UpperCorner': '111.70694732666 -5.86989402770996'}},
#     {'@xmlns:DinasesdmJawaTengah': 'DinasesdmJawaTengah',
#      'Name': 'DinasesdmJawaTengah:gerakan_tanah_jawa_tengah_330020201103112213',
#      'Title': 'Gerakan_Tanah_Jawa_Tengah',
#      'Abstract': 'Gerakan Tanah Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'gerakan_tanah_jawa_tengah_330020201103112213']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540679931641 -8.21053981781006',
#       'ows:UpperCorner': '111.707290649414 -6.40081882476807'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:gereja_di_jawa_tengah_330020220815131454',
#      'Title': 'Gereja_di_Jawa_Tengah_PT',
#      'Abstract': 'Tempat Ibadah Gereja di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'gereja_di_jawa_tengah_330020220815131454']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::3857',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.59673999991445 -8.083709999637385',
#       'ows:UpperCorner': '111.62404000010778 -6.481120000015565'}},
#     {'@xmlns:DinaslhkJawaTengah': 'DinaslhkJawaTengah',
#      'Name': 'DinaslhkJawaTengah:hutan_rakyat_16102018_330020200819105853',
#      'Title': 'Hutan_Rakyat_16/10/2018',
#      'Abstract': 'Hutan Rakyat Provinsi Jawa Tengah (Data 16/10/2018)',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'hutan_rakyat_16102018_330020200819105853']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.53484967643725 -8.220954394981735',
#       'ows:UpperCorner': '111.69909511884994 -6.390313951668957'}},
#     {'@xmlns:DpmptspJawaTengah': 'DpmptspJawaTengah',
#      'Name': 'DpmptspJawaTengah:jalan_eksisting_final_330020200108121209',
#      'Title': 'JALAN_EKSISTING_KLATEN',
#      'Abstract': 'JALAN EKSISTING KLATEN',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jalan_eksisting_final_330020200108121209']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '110.46147899588503 -7.807616121484251',
#       'ows:UpperCorner': '110.78729033028895 -7.566635436504145'}},
#     {'@xmlns:DpubmckJawaTengah': 'DpubmckJawaTengah',
#      'Name': 'DpubmckJawaTengah:jalan_provinsi_ln_25k_330020231228114019',
#      'Title': 'JALAN_PROVINSI_LN_25K',
#      'Abstract': 'Peta Jaringan Jalan Provinsi Jawa Tengah\nSkala 25000\nTahun 2023\nSumber SK Status Jalan Provinsi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jalan_provinsi_ln_25k_330020231228114019']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.683715820312 -8.10873699188232',
#       'ows:UpperCorner': '111.62907409668 -6.47091484069824'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:jaringan_pipa_330020190520102849',
#      'Title': 'JARINGAN_PIPA_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jaringan_pipa_330020190520102849']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.77916552535159 -7.522261249613585',
#       'ows:UpperCorner': '111.77433167929301 -6.2493558222531105'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:jaringan_sutet_330020190520103140',
#      'Title': 'JARINGAN_SUTET_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jaringan_sutet_330020190520103140']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.66318890458037 -7.945133326696399',
#       'ows:UpperCorner': '111.7169853830265 -6.480999452431098'}},
#     {'@xmlns:DpubmckJawaTengah': 'DpubmckJawaTengah',
#      'Name': 'DpubmckJawaTengah:jalan_prov_jateng_bpt_kusus_pusdatin_330020191021205318',
#      'Title': 'Jalan_Prov_Jateng_BPT_kusus_pusdatin',
#      'Abstract': 'Jalan Provinsi Jawa Tengah BPT Khusus PUSDATIN',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jalan_prov_jateng_bpt_kusus_pusdatin_330020191021205318']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.683715820312 -8.06349945068359',
#       'ows:UpperCorner': '111.628868103027 -6.47113990783691'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rs_buffer_14_km_330020200507124457',
#      'Title': 'Jangkauan_Pelayanan_RS_14_km',
#      'Abstract': 'Jangkauan Pelayanan RS 14 km',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rs_buffer_14_km_330020200507124457']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.633043137731 -8.20589722217903',
#       'ows:UpperCorner': '111.712721554156 -6.37595009122367'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rs_buffer_1500_m_330020200507124933',
#      'Title': 'Jangkauan_Pelayanan_RS_1500_m',
#      'Abstract': 'Jangkauan Pelayanan RS 1500 m',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rs_buffer_1500_m_330020200507124933']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.746201222708 -8.0928650054156',
#       'ows:UpperCorner': '111.599599459148 -6.48898202829793'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rs_buffer_3_km_330020200507124644',
#      'Title': 'Jangkauan_Pelayanan_RS_3_km',
#      'Abstract': 'Jangkauan Pelayanan RS 3 km',
#      'ows:Keywords': {'ows:Keyword': ['rs_buffer_3_km_330020200507124644',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.718215942383 -8.11459159851074',
#       'ows:UpperCorner': '111.627578735352 -6.46726322174072'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rs_buffer_7_km_330020200507124602',
#      'Title': 'Jangkauan_Pelayanan_RS_7_km',
#      'Abstract': 'Jangkauan Pelayanan RS 7 km',
#      'ows:Keywords': {'ows:Keyword': ['rs_buffer_7_km_330020200507124602',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.696399968484 -8.14260420911688',
#       'ows:UpperCorner': '111.649384879908 -6.43924803706722'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rencana_jaringan_jalan_330020190617102456',
#      'Title': 'Jaringan Jalan Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rencana_jaringan_jalan_330020190617102456']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.57612308806833 -8.204151419276826',
#       'ows:UpperCorner': '111.69905638910559 -6.473338213467472'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:sungai_jawa_tengah_25k_330020190429153528',
#      'Title': 'Jaringan Sungai Jawa Tengah 25K',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'sungai_jawa_tengah_25k_330020190429153528']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540458679199 -8.22025585174561',
#       'ows:UpperCorner': '111.694534301758 -6.39516448974609'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:jaringan_irigasi_330020190520102617',
#      'Title': 'Jaringan_Irigasi_Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jaringan_irigasi_330020190520102617']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.88796934993276 -7.2158723153089275',
#       'ows:UpperCorner': '111.19781121186114 -6.651633211578252'}},
#     {'@xmlns:Dpusdataru': 'Dpusdataru',
#      'Name': 'Dpusdataru:jaringan_jalan_provinsi_jawa_tengah_330020200826111550',
#      'Title': 'Jaringan_Jalan_Provinsi_Jawa_Tengah',
#      'Abstract': 'Jaringan Jalan Provinsi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'jaringan_jalan_provinsi_jawa_tengah_330020200826111550']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.5376413772404 -8.084729822115316',
#       'ows:UpperCorner': '111.70128234955527 -6.473151297839296'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:kawasan_budidaya_330020190515112635',
#      'Title': 'KAWASAN_BUDIDAYA_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kawasan_budidaya_330020190515112635']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.55176184088506 -8.211746199963404',
#       'ows:UpperCorner': '111.69340891136136 -6.398403540821259'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:kawasan_lindung_330020190515112507',
#      'Title': 'KAWASAN_LINDUNG_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['kawasan_lindung_330020190515112507',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.56108793072697 -8.096921443164478',
#       'ows:UpperCorner': '111.6630011615404 -6.40144851939717'}},
#     {'@xmlns:DinaskpJawaTengah': 'DinaskpJawaTengah',
#      'Name': 'DinaskpJawaTengah:kk_14_330020191021210404',
#      'Title': 'KK_14',
#      'Abstract': 'Kawasan Konservasi',
#      'ows:Keywords': {'ows:Keyword': ['features', 'kk_14_330020191021210404']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.19346848837884 -6.8180207194566',
#       'ows:UpperCorner': '109.20883687390122 -6.805243026153163'}},
#     {'@xmlns:DpmptspJawaTengah': 'DpmptspJawaTengah',
#      'Name': 'DpmptspJawaTengah:kawasan_industri_pt_50k_330020231112233305',
#      'Title': 'Kawasan Industri Jawa Tengah',
#      'Abstract': 'Persebaran Kawasan Industri di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kawasan_industri_pt_50k_330020231112233305']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.798027254087 -7.02509861691988',
#       'ows:UpperCorner': '110.549918647616 -6.92726796389182'}},
#     {'@xmlns:DishubJawaTengah': 'DishubJawaTengah',
#      'Name': 'DishubJawaTengah:lpjukebutuhan_330020191022093245',
#      'Title': 'Kebutuhan LPJU',
#      'Abstract': 'Kebutuhan LPJU di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'lpjukebutuhan_330020191022093245']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '100.93334 -9.16782',
#       'ows:UpperCorner': '111.59681 -6.71564'}},
#     {'@xmlns:Dpusdataru': 'Dpusdataru',
#      'Name': 'Dpusdataru:kew_prov_jateng_di_fungsional_330020211006103256',
#      'Title': 'Kew_Prov_Jateng_DI_Fungsional',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kew_prov_jateng_di_fungsional_330020211006103256']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.727471756 -7.79879953299996',
#       'ows:UpperCorner': '111.270327 -6.43638119499997'}},
#     {'@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#      'Name': 'DispermasdesJawaTengah:klasifikasi_bumdes_jawa_tengah_2019_330020201217104609',
#      'Title': 'Klasifikasi_BUMDes_Jawa_Tengah_2019',
#      'Abstract': 'Klasifikasi BUMDes Jawa Tengah 2019',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'klasifikasi_bumdes_jawa_tengah_2019_330020201217104609']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.671485900879 -8.22111988067627',
#       'ows:UpperCorner': '111.653472900391 -6.37127590179443'}},
#     {'@xmlns:DispermasdesJawaTengah': 'DispermasdesJawaTengah',
#      'Name': 'DispermasdesJawaTengah:klasifikasi_bumdes_jawa_tengah_2020_330020201217104703',
#      'Title': 'Klasifikasi_BUMDes_Jawa_Tengah_2020',
#      'Abstract': 'Klasifikasi BUMDes Jawa Tengah 2020',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'klasifikasi_bumdes_jawa_tengah_2020_330020201217104703']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540321350098 -8.22111988067627',
#       'ows:UpperCorner': '111.678573608398 -6.37127590179443'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:klenteng_di_jawa_tengah_330020220819095859',
#      'Title': 'Klenteng_di_Jawa_Tengah_PT',
#      'Abstract': 'Tempat Ibadah Klenteng di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'klenteng_di_jawa_tengah_330020220819095859']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::3857',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.00895999996112 -7.732659999546502',
#       'ows:UpperCorner': '110.83380999929543 -6.847559999653601'}},
#     {'@xmlns:Dpusdataru': 'Dpusdataru',
#      'Name': 'Dpusdataru:kw_prov_jateng_bendung_330020211006103445',
#      'Title': 'Kw_Prov_Jateng_Bendung',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kw_prov_jateng_bendung_330020211006103445']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.758785128 -7.77458520699997',
#       'ows:UpperCorner': '111.251355 -6.53951843599998'}},
#     {'@xmlns:Dpusdataru': 'Dpusdataru',
#      'Name': 'Dpusdataru:kw_prov_jateng_sal_irigasi_330020211006103610',
#      'Title': 'Kw_Prov_Jateng_Sal_Irigasi',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kw_prov_jateng_sal_irigasi_330020211006103610']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.738060256 -7.78320816499996',
#       'ows:UpperCorner': '111.263334756 -6.43138535599996'}},
#     {'@xmlns:DistanbunJawaTengah': 'DistanbunJawaTengah',
#      'Name': 'DistanbunJawaTengah:lahanp2bjateng1_ar_330020231114080831',
#      'Title': 'LAHANP2BJATENG1_AR',
#      'Abstract': 'Peta LP2B Jawa Tengah\nSkala 50K\nTahun 2022\nSumber Distanbun Jateng',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'lahanp2bjateng1_ar_330020231114080831']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.542274475098 -7.89764738082886',
#       'ows:UpperCorner': '111.704040527344 -6.39706230163574'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:lokas_bank_di_kota_semarang_330020220615141125',
#      'Title': 'Lokasi_Bank_di_Kota_Semarang_PT',
#      'Abstract': 'Titik Lokasi Bank di Kota Semarang',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'lokas_bank_di_kota_semarang_330020220615141125']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '110.3097256 -7.0744938',
#       'ows:UpperCorner': '110.4754686 -6.9482659'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:lokasi_wisata_di_jawa_tengah_330020220808100109',
#      'Title': 'Lokasi_Wisata_di_Jawa_Tengah_PT',
#      'Abstract': 'Lokasi Destinasi Wisata di Provinsi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'lokasi_wisata_di_jawa_tengah_330020220808100109']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.1426666 -7.76022222199992',
#       'ows:UpperCorner': '111.44058 -6.69575999999995'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:mangrove_jawa_tengah_2019_330020210104102956',
#      'Title': 'Mangrove_Jawa_Tengah_2019',
#      'Abstract': 'Mangrove Jawa Tengah 2019',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'mangrove_jawa_tengah_2019_330020210104102956']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.7841320919867 -7.828645557747441',
#       'ows:UpperCorner': '111.44509330929287 -6.40603182275051'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:masjid_di_jawa_tengah_330020220815142410',
#      'Title': 'Masjid_di_Jawa_Tengah_PT',
#      'Abstract': 'Tempat Ibadah Masjid di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'masjid_di_jawa_tengah_330020220815142410']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::3857',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.5837342038074 -8.172125216860428',
#       'ows:UpperCorner': '111.70602660312728 -6.397990392396507'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:pelabuhan_laut_330020190515113639',
#      'Title': 'PELABUHAN_LAUT_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'pelabuhan_laut_330020190515113639']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.95229033278582 -7.741420095002263',
#       'ows:UpperCorner': '111.44069339811583 -6.573889470707134'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:pelabuhan_udara_330020190515114335',
#      'Title': 'PELABUHAN_UDARA_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'pelabuhan_udara_330020190515114335']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.00117224405433 -7.728182351019006',
#       'ows:UpperCorner': '111.5283438863304 -6.964610138040526'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:pengembangan_listrik_330020190520103318',
#      'Title': 'PENGEMBANGAN_LISTRIK_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'pengembangan_listrik_330020190520103318']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.84133056487033 -7.944096082200028',
#       'ows:UpperCorner': '111.56927827532014 -6.428312553429455'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:penggunaantanahjawatengah_ar_25k_330020190515103001',
#      'Title': 'PENGGUNAAN TANAH JAWA TENGAH_AR_25K',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['penggunaantanahjawatengah_ar_25k_330020190515103001',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.548316955566 -7.89844226837158',
#       'ows:UpperCorner': '110.131050109863 -6.96255540847778'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:pasien_covid19_240420_330020200507150712',
#      'Title': 'Pasien_Covid19_Jawa_Tengah_240420',
#      'Abstract': 'Pasien Covid19 Jawa Tengah 240420',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'pasien_covid19_240420_330020200507150712']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.652765232593 -8.07475481656595',
#       'ows:UpperCorner': '111.605733434673 -6.44649421059069'}},
#     {'@xmlns:Dpusdataru': 'Dpusdataru',
#      'Name': 'Dpusdataru:pembagian_wp_provinsi_jawa_tengah_330020200826150415',
#      'Title': 'Pembagian_WP_Provinsi_Jawa_Tengah',
#      'Abstract': 'Pembagian WP Provinsi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'pembagian_wp_provinsi_jawa_tengah_330020200826150415']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.55055890607079 -8.211912280326898',
#       'ows:UpperCorner': '111.69393294586042 -5.721012803632669'}},
#     {'@xmlns:DpmptspJawaTengah': 'DpmptspJawaTengah',
#      'Name': 'DpmptspJawaTengah:kawasan_industri_pt_5k_330020230904140056',
#      'Title': 'Persebaran Kawasan Industri di Jawa Tengah',
#      'Abstract': 'Peta Persebaran Kawasan Industri di Jawa Tengah\nSkala 5K\nTahun 2023\nSumber Bidang Perencanaan dan Pengembangan',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'kawasan_industri_pt_5k_330020230904140056']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.7980273 -6.974403355',
#       'ows:UpperCorner': '110.5499186 -6.927267964'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:potensi_banjir_jateng_12_01_20_330020200225103336',
#      'Title': 'Potensi_Banjir_Jateng_12-01-20',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'potensi_banjir_jateng_12_01_20_330020200225103336']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4030',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.559995209911 -7.50061486938068',
#       'ows:UpperCorner': '110.909049324367 -6.46009709650377'}},
#     {'@xmlns:DinasesdmJawaTengah': 'DinasesdmJawaTengah',
#      'Name': 'DinasesdmJawaTengah:potensi_mineral_batuan_330020231213142741',
#      'Title': 'Potensi_MIneral_Batuan',
#      'Abstract': 'null',
#      'ows:Keywords': {'ows:Keyword': ['potensi_mineral_batuan_330020231213142741',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.7331113175825 -8.157813383126404',
#       'ows:UpperCorner': '111.58017913220834 -6.3993375156107515'}},
#     {'@xmlns:DpmptspJawaTengah': 'DpmptspJawaTengah',
#      'Name': 'DpmptspJawaTengah:proyek_investasi_pt_330020231112234116',
#      'Title': 'Proyek Investasi Jawa Tengah',
#      'Abstract': 'Persebaran Proyek Investasi di Jawa Tengah\nSkala 50.000\nTahun 2023\nSumber https://cjip.jatengprov.go.id/',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'proyek_investasi_pt_330020231112234116']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.751167297363 -7.9170880317688',
#       'ows:UpperCorner': '111.434455871582 -5.81595754623413'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:pura_di_jawa_tengah_330020220816080401',
#      'Title': 'Pura_di_Jawa_Tengah_PT',
#      'Abstract': 'Tempat Ibadah Pura di Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'pura_di_jawa_tengah_330020220816080401']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::3857',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '110.29714999955699 -7.747690000353299',
#       'ows:UpperCorner': '111.1221399994713 -6.984629999843108'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rel_kereta_api_330020190515114711',
#      'Title': 'REL_KERETA_API_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rel_kereta_api_330020190515114711']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.67944824811711 -7.880398395341404',
#       'ows:UpperCorner': '111.6758367062095 -6.714737381582189'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rs_rujukan_virus_corona_jawa_tengah_330020200319090754',
#      'Title': 'RS_Rujukan_Virus_Corona_Jawa_Tengah',
#      'Abstract': '58 Rumah Sakit Rujukan Virus Corona Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rs_rujukan_virus_corona_jawa_tengah_330020200319090754']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.015836213 -7.80489397099996',
#       'ows:UpperCorner': '111.420417462 -6.60609178999994'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rs_rujukan_covid19_jawa_tengah_330020200507150557',
#      'Title': 'RS_dan_Labkes_Rujukan_Covid19_Jawa_Tengah',
#      'Abstract': 'RS dan Labkes Rujukan Covid19 Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rs_rujukan_covid19_jawa_tengah_330020200507150557']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.759783 -8.079311',
#       'ows:UpperCorner': '111.586022 -6.50254582697388'}},
#     {'@xmlns:DisperakimJawaTengah': 'DisperakimJawaTengah',
#      'Name': 'DisperakimJawaTengah:rtlh_2020_apbd_provinsi_jawa_tengah_330020211006133454',
#      'Title': 'RTLH_2020_APBD_Provinsi_Jawa_Tengah',
#      'Abstract': 'RTLH_2020_APBD_Provinsi_Jawa_Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rtlh_2020_apbd_provinsi_jawa_tengah_330020211006133454']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.55585483913 -8.21196175812861',
#       'ows:UpperCorner': '111.677822314448 -5.79406876965794'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rtrwp_330020200106083814',
#      'Title': 'RTRWP  Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features', 'rtrwp_330020200106083814']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540168762207 -8.22096347808838',
#       'ows:UpperCorner': '111.707077026367 -6.37127685546875'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:rumah_pompa_330020220714093447',
#      'Title': 'Rumah_Pompa_di_Kota_Semarang_PT',
#      'Abstract': 'Lokasi Rumah Pompa di Kota Semarang',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'rumah_pompa_330020220714093447']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '110.3075042 -7.09527345251103',
#       'ows:UpperCorner': '110.488912626064 -6.94702014681962'}},
#     {'@xmlns:DisperakimJawaTengah': 'DisperakimJawaTengah',
#      'Name': 'DisperakimJawaTengah:rusun_330020231110093842',
#      'Title': 'Rusun',
#      'Abstract': 'Dinas Perumahan Rakyat dan Kawasan Permukiman Provinsi Jawa Tengah',
#      'ows:Keywords': {'ows:Keyword': ['features', 'rusun_330020231110093842']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '-0.557892858982086 -7.7743992805481',
#       'ows:UpperCorner': '112.13646697998 0.0386786013841629'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:stasiun_kereta_api_330020190515115017',
#      'Title': 'STASIUN_KERETA_API_JAWA TENGAH',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['stasiun_kereta_api_330020190515115017',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.04328499527793 -7.807532111416828',
#       'ows:UpperCorner': '111.64348009193684 -6.719527110711207'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:sarana_stasiun_kereta_api_330020190515114850',
#      'Title': 'Sarana_Stasiun_Kereta_Api_Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'sarana_stasiun_kereta_api_330020190515114850']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.04328499527793 -7.807532111416828',
#       'ows:UpperCorner': '111.64348009193684 -6.719527110711207'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:sarana_terminal_penumpang_330020190515115119',
#      'Title': 'Sarana_Terminal_Penumpang_Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'sarana_terminal_penumpang_330020190515115119']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.04457448137873 -7.815140231574729',
#       'ows:UpperCorner': '111.42414465351888 -6.580700742581305'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:sarana_transportasi_laut_330020190515114048',
#      'Title': 'Sarana_Transportasi_Laut_Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['sarana_transportasi_laut_330020190515114048',
#        'features']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.95229033278582 -7.741420095002263',
#       'ows:UpperCorner': '111.44069339811583 -5.882234992808643'}},
#     {'@xmlns:ADMIN': 'ADMIN',
#      'Name': 'ADMIN:sarana_transportasi_sungai_330020190515113202',
#      'Title': 'Sarana_Transportasi_Sungai_Jawa Tengah',
#      'Abstract': 'undefined',
#      'ows:Keywords': {'ows:Keyword': ['features',
#        'sarana_transportasi_sungai_330020190515113202']},
#      'DefaultCRS': 'urn:ogc:def:crs:EPSG::32749',
#      'ows:WGS84BoundingBox': {'ows:LowerCorner': '109.00095000024898 -7.743493594218809',
#       'ows:UpperCorner': '110.6643422908422 -6.549312534680497'}},
# ...
#         {'@name': 'normalize', 'fes:Type': 'xs:boolean'},
#         {'@name': 'preserveLocation', 'fes:Type': 'xs:string'},
#         {'@name': 'outputBBOX', 'fes:Type': 'xs:string'},
#         {'@name': 'outputWidth', 'fes:Type': 'xs:int'},
#         {'@name': 'outputHeight', 'fes:Type': 'xs:int'}]}},
#      {'@name': 'PolygonExtraction',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'data',
#          'fes:Type': 'xs:string'},
#         {'@name': 'band', 'fes:Type': 'xs:int'},
#         {'@name': 'insideEdges', 'fes:Type': 'xs:boolean'},
#         {'@name': 'roi', 'fes:Type': 'xs:string'},
#         {'@name': 'nodata', 'fes:Type': 'xs:float'},
#         {'@name': 'ranges', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'pow',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'base',
#          'fes:Type': 'xs:float'},
#         {'@name': 'exponent', 'fes:Type': 'xs:float'}]}},
#      {'@name': 'property',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'propertyName',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'PropertyExists',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': {'@name': 'propertyName',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'Quantile',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'value',
#          'fes:Type': 'xs:double'},
#         {'@name': 'classes', 'fes:Type': 'xs:int'}]}},
#      {'@name': 'Query',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'attribute', 'fes:Type': 'xs:string'},
#         {'@name': 'filter', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'random', 'fes:Returns': 'xs:double'},
#      {'@name': 'RangeLookup',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'coverage',
#          'fes:Type': 'xs:string'},
#         {'@name': 'band', 'fes:Type': 'xs:int'},
#         {'@name': 'ranges', 'fes:Type': 'xs:string'},
#         {'@name': 'outputPixelValues', 'fes:Type': 'xs:string'},
#         {'@name': 'noData', 'fes:Type': 'xs:double'}]}},
#      {'@name': 'RasterAsPointCollection',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'data',
#          'fes:Type': 'xs:string'},
#         {'@name': 'targetCRS', 'fes:Type': 'xs:string'},
#         {'@name': 'scale', 'fes:Type': 'xs:float'},
#         {'@name': 'interpolation', 'fes:Type': 'xs:string'},
#         {'@name': 'emisphere', 'fes:Type': 'xs:boolean'}]}},
#      {'@name': 'RasterZonalStatistics',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'data',
#          'fes:Type': 'xs:string'},
#         {'@name': 'band', 'fes:Type': 'xs:int'},
#         {'@name': 'zones', 'fes:Type': 'xs:string'},
#         {'@name': 'classification', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'RasterZonalStatistics2',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'source',
#          'fes:Type': 'xs:string'},
#         {'@name': 'bands', 'fes:Type': 'xs:string'},
#         {'@name': 'zones', 'fes:Type': 'xs:string'},
#         {'@name': 'classifier', 'fes:Type': 'xs:string'},
#         {'@name': 'nodata', 'fes:Type': 'xs:string'},
#         {'@name': 'mask', 'fes:Type': 'xs:string'},
#         {'@name': 'useROIAccessor', 'fes:Type': 'xs:boolean'},
#         {'@name': 'roi', 'fes:Type': 'xs:string'},
#         {'@name': 'statistics', 'fes:Type': 'xs:string'},
#         {'@name': 'minbounds', 'fes:Type': 'xs:string'},
#         {'@name': 'maxbounds', 'fes:Type': 'xs:string'},
#         {'@name': 'numbins', 'fes:Type': 'xs:string'},
#         {'@name': 'rangeData', 'fes:Type': 'xs:string'},
#         {'@name': 'localStats', 'fes:Type': 'xs:boolean'}]}},
#      {'@name': 'Recode',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'LookupValue',
#          'fes:Type': 'xs:string'},
#         {'@name': 'Data 1', 'fes:Type': 'xs:string'},
#         {'@name': 'Value 1', 'fes:Type': 'xs:string'},
#         {'@name': 'Data 2', 'fes:Type': 'xs:string'},
#         {'@name': 'Value 2', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'RectangularClip',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'clip', 'fes:Type': 'xs:string'},
#         {'@name': 'preserveZ', 'fes:Type': 'xs:boolean'}]}},
#      {'@name': 'relate',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry1',
#          'fes:Type': 'xs:string'},
#         {'@name': 'geometry2', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'relatePattern',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry',
#          'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'geometry', 'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'pattern', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'Reproject',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'forcedCRS', 'fes:Type': 'xs:string'},
#         {'@name': 'targetCRS', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'rescaleToPixels',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'value',
#          'fes:Type': 'xs:string'},
#         {'@name': 'defaultUnit', 'fes:Type': 'xs:string'},
#         {'@name': 'scaleFactor', 'fes:Type': 'xs:double'},
#         {'@name': 'rescalingMode', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'rint',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'double',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'round',
#       'fes:Returns': 'xs:float',
#       'fes:Arguments': {'fes:Argument': {'@name': 'number',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'round_2',
#       'fes:Returns': 'xs:long',
#       'fes:Arguments': {'fes:Argument': {'@name': 'number',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'roundDouble',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'number',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'ScaleCoverage',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'coverage',
#          'fes:Type': 'xs:string'},
#         {'@name': 'xScale', 'fes:Type': 'xs:double'},
#         {'@name': 'yScale', 'fes:Type': 'xs:double'},
#         {'@name': 'xTranslate', 'fes:Type': 'xs:double'},
#         {'@name': 'yTranslate', 'fes:Type': 'xs:double'},
#         {'@name': 'interpolation', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'setCRS',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry',
#          'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'CRS', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'Simplify',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'distance', 'fes:Type': 'xs:double'},
#         {'@name': 'preserveTopology', 'fes:Type': 'xs:boolean'}]}},
#      {'@name': 'sin',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'radians',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'Snap',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'point', 'fes:Type': 'xs:string'},
#         {'@name': 'crs', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'sqrt',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'number',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'StandardDeviation',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'value',
#          'fes:Type': 'xs:double'},
#         {'@name': 'classes', 'fes:Type': 'xs:int'}]}},
#      {'@name': 'startAngle',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'linestring',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'startPoint',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'linestring',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'strCapitalize',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'string',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'strConcat',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string1',
#          'fes:Type': 'xs:string'},
#         {'@name': 'string2', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strEndsWith',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'String',
#          'fes:Type': 'xs:string'},
#         {'@name': 'postfix', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strEqualsIgnoreCase',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'lookup', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strIndexOf',
#       'fes:Returns': 'xs:int',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'String',
#          'fes:Type': 'xs:string'},
#         {'@name': 'lookup', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'stringTemplate',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'input',
#          'fes:Type': 'xs:string'},
#         {'@name': 'pattern', 'fes:Type': 'xs:string'},
#         {'@name': 'template', 'fes:Type': 'xs:string'},
#         {'@name': 'defaultValue', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strLastIndexOf',
#       'fes:Returns': 'xs:int',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'String',
#          'fes:Type': 'xs:string'},
#         {'@name': 'lookup', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strLength',
#       'fes:Returns': 'xs:int',
#       'fes:Arguments': {'fes:Argument': {'@name': 'string',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'strMatches',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'regex', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strPosition',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'lookup', 'fes:Type': 'xs:string'},
#         {'@name': 'method', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strReplace',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'search', 'fes:Type': 'xs:string'},
#         {'@name': 'replace', 'fes:Type': 'xs:string'},
#         {'@name': 'all', 'fes:Type': 'xs:boolean'}]}},
#      {'@name': 'strStartsWith',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'prefix', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'strSubstring',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'beginIndex', 'fes:Type': 'xs:int'},
#         {'@name': 'endIndex', 'fes:Type': 'xs:int'}]}},
#      {'@name': 'strSubstringStart',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'beginIndex', 'fes:Type': 'xs:int'}]}},
#      {'@name': 'strToLowerCase',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'string',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'strToUpperCase',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'string',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'strTrim',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'string',
#         'fes:Type': 'xs:string'}}},
#      {'@name': 'strTrim2',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'string',
#          'fes:Type': 'xs:string'},
#         {'@name': 'method', 'fes:Type': 'xs:string'},
#         {'@name': 'character', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'StyleCoverage',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'coverage',
#          'fes:Type': 'xs:string'},
#         {'@name': 'style', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'symDifference',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry',
#          'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'geometry', 'fes:Type': 'gml:AbstractGeometryType'}]}},
#      {'@name': 'tan',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'radians',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'toDegrees',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'radians',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'toRadians',
#       'fes:Returns': 'xs:double',
#       'fes:Arguments': {'fes:Argument': {'@name': 'degree',
#         'fes:Type': 'xs:float'}}},
#      {'@name': 'touches',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry',
#          'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'geometry', 'fes:Type': 'gml:AbstractGeometryType'}]}},
#      {'@name': 'toWKT',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'geometry',
#         'fes:Type': 'gml:AbstractGeometryType'}}},
#      {'@name': 'Transform',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'transform', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'union',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry',
#          'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'geometry', 'fes:Type': 'gml:AbstractGeometryType'}]}},
#      {'@name': 'UnionFeatureCollection',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'first',
#          'fes:Type': 'xs:string'},
#         {'@name': 'second', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'Unique',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'attribute', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'UniqueInterval',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'value',
#          'fes:Type': 'xs:double'},
#         {'@name': 'classes', 'fes:Type': 'xs:int'}]}},
#      {'@name': 'VectorToRaster',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'features',
#          'fes:Type': 'xs:string'},
#         {'@name': 'rasterWidth', 'fes:Type': 'xs:int'},
#         {'@name': 'rasterHeight', 'fes:Type': 'xs:int'},
#         {'@name': 'title', 'fes:Type': 'xs:string'},
#         {'@name': 'attribute', 'fes:Type': 'xs:string'},
#         {'@name': 'bounds', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'VectorZonalStatistics',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'data',
#          'fes:Type': 'xs:string'},
#         {'@name': 'dataAttribute', 'fes:Type': 'xs:string'},
#         {'@name': 'zones', 'fes:Type': 'xs:string'}]}},
#      {'@name': 'vertices',
#       'fes:Returns': 'xs:string',
#       'fes:Arguments': {'fes:Argument': {'@name': 'geometry',
#         'fes:Type': 'gml:AbstractGeometryType'}}},
#      {'@name': 'within',
#       'fes:Returns': 'xs:boolean',
#       'fes:Arguments': {'fes:Argument': [{'@name': 'geometry',
#          'fes:Type': 'gml:AbstractGeometryType'},
#         {'@name': 'geometry', 'fes:Type': 'gml:AbstractGeometryType'}]}}]}}}}

# %%
data.keys()
# Out:
# dict_keys(['wfs:WFS_Capabilities'])

# %%
list(
  data['wfs:WFS_Capabilities'].keys()
)
# Out:
# ['@xmlns:xsi',
#  '@xmlns',
#  '@xmlns:wfs',
#  '@xmlns:ows',
#  '@xmlns:gml',
#  '@xmlns:fes',
#  '@xmlns:xlink',
#  '@xmlns:xs',
#  '@xmlns:xml',
#  '@xmlns:OPDJATENG',
#  '@xmlns:DishanpanJawaTengah',
#  '@xmlns:DisdikbudJawaTengah',
#  '@xmlns:Satpolpp',
#  '@xmlns:BappedaJawaTengah',
#  '@xmlns:DinaskpJawaTengah',
#  '@xmlns:DisporaparJawaTengah',
#  '@xmlns:DistanbunJawaTengah',
#  '@xmlns:Dpusdataru',
#  '@xmlns:BKDJawaTengah',
#  '@xmlns:DinasesdmJawaTengah',
#  '@xmlns:DpubmckJawaTengah',
#  '@xmlns:DinaslhkJawaTengah',
#  '@xmlns:BiroPemotdaksJawaTengah',
#  '@xmlns:DishubJawaTengah',
#  '@xmlns:DisperindagJawaTengah',
#  '@xmlns:DisnakertransJawaTengah',
#  '@xmlns:ADMIN',
#  '@xmlns:DisperakimJawaTengah',
#  '@xmlns:DinkopukmJawaTengah',
#  '@xmlns:DiskominfoJawaTengah',
#  '@xmlns:DinkesJawaTengah',
#  '@xmlns:DispermasdesJawaTengah',
#  '@xmlns:Kabkota',
#  '@xmlns:Kesbangpol',
#  '@xmlns:KUGI',
#  '@xmlns:Walidatadaerah',
#  '@xmlns:DinsosJawaTengah',
#  '@xmlns:DisnakeswanJawaTengah',
#  '@xmlns:BPBDJawaTengah',
#  '@xmlns:BapendaJawaTengah',
#  '@xmlns:BPKADJawaTengah',
#  '@xmlns:geodata',
#  '@xmlns:DpmptspJawaTengah',
#  '@version',
#  '@xsi:schemaLocation',
#  '@updateSequence',
#  'ows:ServiceIdentification',
#  'ows:ServiceProvider',
#  'ows:OperationsMetadata',
#  'FeatureTypeList',
#  'fes:Filter_Capabilities']

# %%
for key in data['wfs:WFS_Capabilities'].keys():
  if "@" not in key:
    print(key)
# Out:
# ows:ServiceIdentification
# ows:ServiceProvider
# ows:OperationsMetadata
# FeatureTypeList
# fes:Filter_Capabilities

# %%
capabilities = data['wfs:WFS_Capabilities']

# %%
service_id = capabilities['ows:ServiceIdentification']

service_id
# Out:
# {'ows:Title': 'GeoServer Web Feature Service',
#  'ows:Abstract': 'This is the reference implementation of WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.',
#  'ows:Keywords': {'ows:Keyword': ['WFS', 'WMS', 'GEOSERVER']},
#  'ows:ServiceType': 'WFS',
#  'ows:ServiceTypeVersion': '2.0.0',
#  'ows:Fees': 'NONE',
#  'ows:AccessConstraints': 'NONE'}

# %% [markdown]
# ## Fetch provider data

# %%
service_provider = capabilities['ows:ServiceProvider']

service_provider
# Out:
# {'ows:ProviderName': 'Provinsi Jawa Tengah',
#  'ows:ServiceContact': {'ows:IndividualName': '(024) 8319140',
#   'ows:PositionName': 'Jl. Menteri Supeno 1 / 2 , Semarang 50243',
#   'ows:ContactInfo': {'ows:Phone': {'ows:Voice': None,
#     'ows:Facsimile': '(024) 8443916'},
#    'ows:Address': {'ows:DeliveryPoint': None,
#     'ows:City': 'Semarang',
#     'ows:AdministrativeArea': 'Jawa Tengah',
#     'ows:PostalCode': '50243',
#     'ows:Country': 'Indonesia',
#     'ows:ElectronicMailAddress': 'diskominfo@jatengprov.go.id'}}}}

# %%
provider_name = service_provider['ows:ProviderName']

provider_name
# Out:
# 'Provinsi Jawa Tengah'

# %%
provider_phone = service_provider['ows:ServiceContact']['ows:IndividualName']

provider_phone
# Out:
# '(024) 8319140'

# %%
address_dict = service_provider['ows:ServiceContact']['ows:ContactInfo']['ows:Address']

address_dict
# Out:
# {'ows:DeliveryPoint': None,
#  'ows:City': 'Semarang',
#  'ows:AdministrativeArea': 'Jawa Tengah',
#  'ows:PostalCode': '50243',
#  'ows:Country': 'Indonesia',
#  'ows:ElectronicMailAddress': 'diskominfo@jatengprov.go.id'}

# %%
provider_address = "%s, %s, %s %s" % (
  address_dict['ows:City'],
  address_dict['ows:AdministrativeArea'],
  address_dict['ows:Country'],
  address_dict['ows:PostalCode'],
)

provider_address
# Out:
# 'Semarang, Jawa Tengah, Indonesia 50243'

# %%
provider_email = address_dict['ows:ElectronicMailAddress']

provider_email
# Out:
# 'diskominfo@jatengprov.go.id'

# %% [markdown]
# ### Fetch feature list

# %%
feature_list = capabilities['FeatureTypeList']

feature_list.keys()
# Out:
# dict_keys(['FeatureType'])

# %%
feature_list['FeatureType'][0]
# Out:
# {'@xmlns:ADMIN': 'ADMIN',
#  'Name': 'ADMIN:adm_jateng_bts_desa_250k_330020200517094901',
#  'Title': 'ADM_JATENG_BTS_DESA_250K',
#  'Abstract': 'ADM_JATENG_BTS_DESA_250K',
#  'ows:Keywords': {'ows:Keyword': ['features',
#    'adm_jateng_bts_desa_250k_330020200517094901']},
#  'DefaultCRS': 'urn:ogc:def:crs:EPSG::4326',
#  'ows:WGS84BoundingBox': {'ows:LowerCorner': '108.540176391602 -8.22111988067627',
#   'ows:UpperCorner': '111.707092285156 -6.37127590179443'}}

# %%
feature_list['FeatureType'][0]["Name"]
# Out:
# 'ADMIN:adm_jateng_bts_desa_250k_330020200517094901'

# %%
for feature in feature_list['FeatureType']:
  print(feature["Name"])
# Out:
# ADMIN:adm_jateng_bts_desa_250k_330020200517094901
# ADMIN:adm_semarang_bts_rw_330020220720082500
# DispermasdesJawaTengah:air_minum_kemasan_jawa_tengah_330020201116102906
# DispermasdesJawaTengah:air_minum_ledeng_jawa_tengah_330020201116103129
# DispermasdesJawaTengah:air_minum_sumber_lainnya_jawa_tengah_330020201116103303
# DispermasdesJawaTengah:air_minum_sumber_terlindungi_jawa_tengah_330020201116103538
# ADMIN:adm_jateng_bts_kabupaten_kota_250k_330020190617103125
# ADMIN:adm_jateng_bts_kecamatan_250k_330020190617103256
# ADMIN:budidaya_rumput_laut_jawa_tengah_2018_330020210104114146
# DinasesdmJawaTengah:cat_jateng_region_330020231213140345
# ADMIN:candi_di_jawa_tengah_330020220822074546
# DinasesdmJawaTengah:cekungan_air_tanah_jawa_tengah_330020201112100857
# ADMIN:depo_bbm_330020190515113348
# Dpusdataru:danau_provinsi_jawa_tengah_330020200826142727
# DisporaparJawaTengah:daya_tarik_wisata_pt_330020231227082506
# ADMIN:fasilitas_kesehatan_vaksinasi_jawa_tengah_330020210426124814
# DisporaparJawaTengah:geospasial_deswita_pt_330020231227082250
# ADMIN:kontur_330020190510095118
# ADMIN:garispantaijawatengah_ln_25k_330020190515102758
# ADMIN:geologi_jawa_tengah_330020210419095955
# DinasesdmJawaTengah:gerakan_tanah_jawa_tengah_330020201103112213
# ADMIN:gereja_di_jawa_tengah_330020220815131454
# DinaslhkJawaTengah:hutan_rakyat_16102018_330020200819105853
# DpmptspJawaTengah:jalan_eksisting_final_330020200108121209
# DpubmckJawaTengah:jalan_provinsi_ln_25k_330020231228114019
# ADMIN:jaringan_pipa_330020190520102849
# ADMIN:jaringan_sutet_330020190520103140
# DpubmckJawaTengah:jalan_prov_jateng_bpt_kusus_pusdatin_330020191021205318
# ADMIN:rs_buffer_14_km_330020200507124457
# ADMIN:rs_buffer_1500_m_330020200507124933
# ADMIN:rs_buffer_3_km_330020200507124644
# ADMIN:rs_buffer_7_km_330020200507124602
# ADMIN:rencana_jaringan_jalan_330020190617102456
# ADMIN:sungai_jawa_tengah_25k_330020190429153528
# ADMIN:jaringan_irigasi_330020190520102617
# Dpusdataru:jaringan_jalan_provinsi_jawa_tengah_330020200826111550
# ADMIN:kawasan_budidaya_330020190515112635
# ADMIN:kawasan_lindung_330020190515112507
# DinaskpJawaTengah:kk_14_330020191021210404
# DpmptspJawaTengah:kawasan_industri_pt_50k_330020231112233305
# DishubJawaTengah:lpjukebutuhan_330020191022093245
# Dpusdataru:kew_prov_jateng_di_fungsional_330020211006103256
# DispermasdesJawaTengah:klasifikasi_bumdes_jawa_tengah_2019_330020201217104609
# DispermasdesJawaTengah:klasifikasi_bumdes_jawa_tengah_2020_330020201217104703
# ADMIN:klenteng_di_jawa_tengah_330020220819095859
# Dpusdataru:kw_prov_jateng_bendung_330020211006103445
# Dpusdataru:kw_prov_jateng_sal_irigasi_330020211006103610
# DistanbunJawaTengah:lahanp2bjateng1_ar_330020231114080831
# ADMIN:lokas_bank_di_kota_semarang_330020220615141125
# ADMIN:lokasi_wisata_di_jawa_tengah_330020220808100109
# ADMIN:mangrove_jawa_tengah_2019_330020210104102956
# ADMIN:masjid_di_jawa_tengah_330020220815142410
# ADMIN:pelabuhan_laut_330020190515113639
# ADMIN:pelabuhan_udara_330020190515114335
# ADMIN:pengembangan_listrik_330020190520103318
# ADMIN:penggunaantanahjawatengah_ar_25k_330020190515103001
# ADMIN:pasien_covid19_240420_330020200507150712
# Dpusdataru:pembagian_wp_provinsi_jawa_tengah_330020200826150415
# DpmptspJawaTengah:kawasan_industri_pt_5k_330020230904140056
# ADMIN:potensi_banjir_jateng_12_01_20_330020200225103336
# DinasesdmJawaTengah:potensi_mineral_batuan_330020231213142741
# DpmptspJawaTengah:proyek_investasi_pt_330020231112234116
# ADMIN:pura_di_jawa_tengah_330020220816080401
# ADMIN:rel_kereta_api_330020190515114711
# ADMIN:rs_rujukan_virus_corona_jawa_tengah_330020200319090754
# ADMIN:rs_rujukan_covid19_jawa_tengah_330020200507150557
# DisperakimJawaTengah:rtlh_2020_apbd_provinsi_jawa_tengah_330020211006133454
# ADMIN:rtrwp_330020200106083814
# ADMIN:rumah_pompa_330020220714093447
# DisperakimJawaTengah:rusun_330020231110093842
# ADMIN:stasiun_kereta_api_330020190515115017
# ADMIN:sarana_stasiun_kereta_api_330020190515114850
# ADMIN:sarana_terminal_penumpang_330020190515115119
# ADMIN:sarana_transportasi_laut_330020190515114048
# ADMIN:sarana_transportasi_sungai_330020190515113202
# ADMIN:sarana_transportasi_udara_330020190515114514
# DishubJawaTengah:shelter_330020231106080821
# ADMIN:sistem_lahan_jawa_tengah_330020190515110117
# ADMIN:stasiun_pompa_bahan_bakar_umum_330020220613104935
# Dpusdataru:sungai_provinsi_jawa_tengah_330020200826142826
# ADMIN:supermarket_330020220713132235
# ADMIN:terminal_angkutan_penumpang_330020190515115221
# DishubJawaTengah:terminaltipeb_330020191022084025
# ADMIN:tipe_gunung_api_jawa_tengah_pt_330020221101090631
# BapendaJawaTengah:samsat_pt_330020230705100335
# ADMIN:titik_pusat_kota_330020190429145333
# ADMIN:titik_pusat_kota_kecamatan_330020190429145442
# Dpusdataru:toponimi_daratan_provinsi_jawa_tengah_330020200826143011
# Dpusdataru:toponimi_pulau_provinsi_jawa_tengah_330020200826143119
# Dpusdataru:tutupan_lahan_provinsi_jawa_tengah_330020200826103158
# DinkopukmJawaTengah:umkm_jawa_tengah_shogit_330020200728104215
# ADMIN:wihara_di_jawa_tengah_330020220818073021
# DpmptspJawaTengah:peluang_potensi_investasi_jawa_tengah_330020200623083723
# DisperakimJawaTengah:twii_kedungsepur_rtlh_330020191021205516

# %% [markdown]
# ## Process feature CRS

# %%
for feature in feature_list['FeatureType']:
  if feature["Name"] == "ADMIN:candi_di_jawa_tengah_330020220822074546":
    crs_candi = feature['DefaultCRS']

crs_candi
# Out:
# 'urn:ogc:def:crs:EPSG::3857'

# %% [markdown]
# ### Process GeoJSON WFS

# %%
gdf_geojson = gpd.read_file("../../extract/output/wfs_get_feature.geojson")

gdf_geojson.head()
# Out:
#                                           id objectid  fgsprp metadata  \
# 0  candi_di_jawa_tengah_330020220822074546.1     3155     999     None
# 1  candi_di_jawa_tengah_330020220822074546.2      859     999     None
# 2  candi_di_jawa_tengah_330020220822074546.3     7605     999     None
# 3  candi_di_jawa_tengah_330020220822074546.4     7606     999     None
# 4  candi_di_jawa_tengah_330020220822074546.5     7607     999     None
#
#         fcode             namaobj srs_id remark       wadmpr  \
# 0  GF01030020     CANDI PRAMBANAN   None  CANDI  JAWA TENGAH
# 1  GF01030020     CANDI BOROBUDUR   None  CANDI  JAWA TENGAH
# 2  GF01030020        CANDI MENDUT   None  CANDI  JAWA TENGAH
# 3  GF01030020  CANDI GEDONG SONGO   None  CANDI  JAWA TENGAH
# 4  GF01030020         CANDI PAWON   None  CANDI  JAWA TENGAH
#
#                                         alamat  \
# 0  JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN
# 1            JL. BADRAWATI, KW CANDI BOROBUDUR
# 2                     JL. MAYOR KUSEN, MUNGKID
# 3       JALAN KE CANDI GEDONG SONGO, BANDUNGAN
# 4                        BROJONALAN, BOROBUDUR
#
#                                     laman                          geometry
# 0  https://gis.dukcapil.kemendagri.go.id/   POINT (12300339.53 -865858.732)
# 1  https://gis.dukcapil.kemendagri.go.id/  POINT (12267833.292 -849414.049)
# 2  https://gis.dukcapil.kemendagri.go.id/  POINT (12270760.639 -849061.485)
# 3  https://gis.dukcapil.kemendagri.go.id/  POINT (12283195.041 -804530.014)
# 4  https://gis.dukcapil.kemendagri.go.id/  POINT (12269585.084 -849208.193)

# %%
gdf_geojson.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Process Geospatial CSV

# %%
gdf_csv = gpd.read_file("../../extract/output/wfs_get_feature.csv")

gdf_csv.head()
# Out:
#                                          FID  \
# 0  candi_di_jawa_tengah_330020220822074546.1
# 1  candi_di_jawa_tengah_330020220822074546.2
# 2  candi_di_jawa_tengah_330020220822074546.3
# 3  candi_di_jawa_tengah_330020220822074546.4
# 4  candi_di_jawa_tengah_330020220822074546.5
#
#                                     wkb_geometry objectid fgsprp metadata  \
# 0       POINT (12300339.5304 -865858.7320999987)     3155    999
# 1  POINT (12267833.292157529 -849414.0494921235)      859    999
# 2  POINT (12270760.638897741 -849061.4847741559)     7605    999
# 3   POINT (12283195.04058327 -804530.0135457712)     7606    999
# 4  POINT (12269585.084492296 -849208.1932091843)     7607    999
#
#         fcode             namaobj srs_id remark       wadmpr  \
# 0  GF01030020     CANDI PRAMBANAN         CANDI  JAWA TENGAH
# 1  GF01030020     CANDI BOROBUDUR         CANDI  JAWA TENGAH
# 2  GF01030020        CANDI MENDUT         CANDI  JAWA TENGAH
# 3  GF01030020  CANDI GEDONG SONGO         CANDI  JAWA TENGAH
# 4  GF01030020         CANDI PAWON         CANDI  JAWA TENGAH
#
#                                         alamat  \
# 0  JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN
# 1            JL. BADRAWATI, KW CANDI BOROBUDUR
# 2                     JL. MAYOR KUSEN, MUNGKID
# 3       JALAN KE CANDI GEDONG SONGO, BANDUNGAN
# 4                        BROJONALAN, BOROBUDUR
#
#                                     laman
# 0  https://gis.dukcapil.kemendagri.go.id/
# 1  https://gis.dukcapil.kemendagri.go.id/
# 2  https://gis.dukcapil.kemendagri.go.id/
# 3  https://gis.dukcapil.kemendagri.go.id/
# 4  https://gis.dukcapil.kemendagri.go.id/

# %%
gdf_csv.crs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/x2/fsb9vgcn65d5s9nbfh7b7p2r0000gn/T/ipykernel_62143/2491260488.py in ?()
# ----> 1 gdf_csv.crs
#
# ~/Documents/Faiz/GitHub/Personal Project/geocourse-data-engineering/venv/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'crs'

# %%
gdf_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FID           8 non-null      object
#  1   wkb_geometry  8 non-null      object
#  2   objectid      8 non-null      object
#  3   fgsprp        8 non-null      object
#  4   metadata      8 non-null      object
#  5   fcode         8 non-null      object
#  6   namaobj       8 non-null      object
#  7   srs_id        8 non-null      object
#  8   remark        8 non-null      object
#  9   wadmpr        8 non-null      object
#  10  alamat        8 non-null      object
#  11  laman         8 non-null      object
# dtypes: object(12)
# memory usage: 900.0+ bytes

# %%
gdf_csv["geometry"] = gdf_csv["wkb_geometry"].apply(lambda row: wkt.loads(row))

gdf_csv.head()
# Out:
#                                          FID  \
# 0  candi_di_jawa_tengah_330020220822074546.1
# 1  candi_di_jawa_tengah_330020220822074546.2
# 2  candi_di_jawa_tengah_330020220822074546.3
# 3  candi_di_jawa_tengah_330020220822074546.4
# 4  candi_di_jawa_tengah_330020220822074546.5
#
#                                     wkb_geometry objectid fgsprp metadata  \
# 0       POINT (12300339.5304 -865858.7320999987)     3155    999
# 1  POINT (12267833.292157529 -849414.0494921235)      859    999
# 2  POINT (12270760.638897741 -849061.4847741559)     7605    999
# 3   POINT (12283195.04058327 -804530.0135457712)     7606    999
# 4  POINT (12269585.084492296 -849208.1932091843)     7607    999
#
#         fcode             namaobj srs_id remark       wadmpr  \
# 0  GF01030020     CANDI PRAMBANAN         CANDI  JAWA TENGAH
# 1  GF01030020     CANDI BOROBUDUR         CANDI  JAWA TENGAH
# 2  GF01030020        CANDI MENDUT         CANDI  JAWA TENGAH
# 3  GF01030020  CANDI GEDONG SONGO         CANDI  JAWA TENGAH
# 4  GF01030020         CANDI PAWON         CANDI  JAWA TENGAH
#
#                                         alamat  \
# 0  JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN
# 1            JL. BADRAWATI, KW CANDI BOROBUDUR
# 2                     JL. MAYOR KUSEN, MUNGKID
# 3       JALAN KE CANDI GEDONG SONGO, BANDUNGAN
# 4                        BROJONALAN, BOROBUDUR
#
#                                     laman  \
# 0  https://gis.dukcapil.kemendagri.go.id/
# 1  https://gis.dukcapil.kemendagri.go.id/
# 2  https://gis.dukcapil.kemendagri.go.id/
# 3  https://gis.dukcapil.kemendagri.go.id/
# 4  https://gis.dukcapil.kemendagri.go.id/
#
#                                         geometry
# 0       POINT (12300339.5304 -865858.7320999987)
# 1  POINT (12267833.292157529 -849414.0494921235)
# 2  POINT (12270760.638897741 -849061.4847741559)
# 3   POINT (12283195.04058327 -804530.0135457712)
# 4  POINT (12269585.084492296 -849208.1932091843)

# %%
gdf_geo_csv = gpd.GeoDataFrame(gdf_csv, geometry="geometry", crs=crs_candi)

gdf_geo_csv.head()
# Out:
#                                          FID  \
# 0  candi_di_jawa_tengah_330020220822074546.1
# 1  candi_di_jawa_tengah_330020220822074546.2
# 2  candi_di_jawa_tengah_330020220822074546.3
# 3  candi_di_jawa_tengah_330020220822074546.4
# 4  candi_di_jawa_tengah_330020220822074546.5
#
#                                     wkb_geometry objectid fgsprp metadata  \
# 0       POINT (12300339.5304 -865858.7320999987)     3155    999
# 1  POINT (12267833.292157529 -849414.0494921235)      859    999
# 2  POINT (12270760.638897741 -849061.4847741559)     7605    999
# 3   POINT (12283195.04058327 -804530.0135457712)     7606    999
# 4  POINT (12269585.084492296 -849208.1932091843)     7607    999
#
#         fcode             namaobj srs_id remark       wadmpr  \
# 0  GF01030020     CANDI PRAMBANAN         CANDI  JAWA TENGAH
# 1  GF01030020     CANDI BOROBUDUR         CANDI  JAWA TENGAH
# 2  GF01030020        CANDI MENDUT         CANDI  JAWA TENGAH
# 3  GF01030020  CANDI GEDONG SONGO         CANDI  JAWA TENGAH
# 4  GF01030020         CANDI PAWON         CANDI  JAWA TENGAH
#
#                                         alamat  \
# 0  JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN
# 1            JL. BADRAWATI, KW CANDI BOROBUDUR
# 2                     JL. MAYOR KUSEN, MUNGKID
# 3       JALAN KE CANDI GEDONG SONGO, BANDUNGAN
# 4                        BROJONALAN, BOROBUDUR
#
#                                     laman                          geometry
# 0  https://gis.dukcapil.kemendagri.go.id/   POINT (12300339.53 -865858.732)
# 1  https://gis.dukcapil.kemendagri.go.id/  POINT (12267833.292 -849414.049)
# 2  https://gis.dukcapil.kemendagri.go.id/  POINT (12270760.639 -849061.485)
# 3  https://gis.dukcapil.kemendagri.go.id/  POINT (12283195.041 -804530.014)
# 4  https://gis.dukcapil.kemendagri.go.id/  POINT (12269585.084 -849208.193)

# %%
gdf_geo_csv.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Process GML

# %%
file_path = "../../extract/output/wfs_get_feature.xml"

# %%
gdf_gml = gpd.read_file(file_path)

gdf_gml.head()
# Out:
#                                       gml_id  objectid  fgsprp       fcode  \
# 0  candi_di_jawa_tengah_330020220822074546.1      3155     999  GF01030020
# 1  candi_di_jawa_tengah_330020220822074546.2       859     999  GF01030020
# 2  candi_di_jawa_tengah_330020220822074546.3      7605     999  GF01030020
# 3  candi_di_jawa_tengah_330020220822074546.4      7606     999  GF01030020
# 4  candi_di_jawa_tengah_330020220822074546.5      7607     999  GF01030020
#
#               namaobj remark       wadmpr  \
# 0     CANDI PRAMBANAN  CANDI  JAWA TENGAH
# 1     CANDI BOROBUDUR  CANDI  JAWA TENGAH
# 2        CANDI MENDUT  CANDI  JAWA TENGAH
# 3  CANDI GEDONG SONGO  CANDI  JAWA TENGAH
# 4         CANDI PAWON  CANDI  JAWA TENGAH
#
#                                         alamat  \
# 0  JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN
# 1            JL. BADRAWATI, KW CANDI BOROBUDUR
# 2                     JL. MAYOR KUSEN, MUNGKID
# 3       JALAN KE CANDI GEDONG SONGO, BANDUNGAN
# 4                        BROJONALAN, BOROBUDUR
#
#                                     laman                          geometry
# 0  https://gis.dukcapil.kemendagri.go.id/   POINT (12300339.53 -865858.732)
# 1  https://gis.dukcapil.kemendagri.go.id/  POINT (12267833.292 -849414.049)
# 2  https://gis.dukcapil.kemendagri.go.id/  POINT (12270760.639 -849061.485)
# 3  https://gis.dukcapil.kemendagri.go.id/  POINT (12283195.041 -804530.014)
# 4  https://gis.dukcapil.kemendagri.go.id/  POINT (12269585.084 -849208.193)

# %%
gdf_gml.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Process KML

# %%
file_path = '../../extract/output/wfs_get_feature.kml'

# %%
gpd.read_file(file_path, driver="KML")
# Out:
#   Name Description                    geometry
# 0                   POINT (110.49583 -7.75436)
# 1                   POINT (110.20382 -7.60796)
# 2                   POINT (110.23012 -7.60482)
# 3                   POINT (110.34182 -7.20813)
# 4                   POINT (110.21956 -7.60613)
# 5                   POINT (110.49603 -7.76105)
# 6                   POINT (110.50465 -7.74055)
# 7                   POINT (109.90692 -7.20504)

# %%
tree = ET.parse(file_path)
root = tree.getroot()

root
# Out:
# <Element '{http://www.opengis.net/kml/2.2}kml' at 0x1327b19e0>

# %%
namespace = {"kml": "http://www.opengis.net/kml/2.2"}

# %%
placemarks = root.findall(".//kml:Placemark", namespace)

placemarks
# Out:
# [<Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x132248ea0>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x132248590>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x13222e570>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x13222f3d0>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x13222eca0>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x13222f100>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x13222e7f0>,
#  <Element '{http://www.opengis.net/kml/2.2}Placemark' at 0x13222f8d0>]

# %%
placemark_data = []

for placemark in placemarks:
  placemark_output = {}
  placemark_output["id"] = placemark.get("id")

  # fetch geometry
  point_geom = placemark.find(".//kml:Point", namespace)
  if point_geom is not None:
    longitude, latitude = placemark.find(".//kml:coordinates", namespace).text.split(",")
    geom = Point(longitude, latitude)
    placemark_output["geometry"] = geom

  # fetch attribute data
  schema = placemark.find(".//kml:SchemaData", namespace)
  if schema is not None:
    data = schema.findall("kml:SimpleData", namespace)
    for item in data:
      attribute = item.get("name")
      content = item.text
      placemark_output[attribute] = content

  placemark_data.append(placemark_output)

placemark_data
# Out:
# [{'id': 'candi_di_jawa_tengah_330020220822074546.1',
#   'geometry': <POINT (110.496 -7.754)>,
#   'objectid': '3155',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI PRAMBANAN',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.2',
#   'geometry': <POINT (110.204 -7.608)>,
#   'objectid': '859',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI BOROBUDUR',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'JL. BADRAWATI, KW CANDI BOROBUDUR',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.3',
#   'geometry': <POINT (110.23 -7.605)>,
#   'objectid': '7605',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI MENDUT',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'JL. MAYOR KUSEN, MUNGKID',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.4',
#   'geometry': <POINT (110.342 -7.208)>,
#   'objectid': '7606',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI GEDONG SONGO',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'JALAN KE CANDI GEDONG SONGO, BANDUNGAN',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.5',
#   'geometry': <POINT (110.22 -7.606)>,
#   'objectid': '7607',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI PAWON',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'BROJONALAN, BOROBUDUR',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.6',
#   'geometry': <POINT (110.496 -7.761)>,
#   'objectid': '7608',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI SOJIWAN',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'KEBON DALEM KIDUL, PRAMBANAN',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.7',
#   'geometry': <POINT (110.505 -7.741)>,
#   'objectid': '7609',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI PLAOSAN',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'JL. CANDI PLAOSAN, PRAMBANAN',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'},
#  {'id': 'candi_di_jawa_tengah_330020220822074546.8',
#   'geometry': <POINT (109.907 -7.205)>,
#   'objectid': '7610',
#   'fgsprp': '999',
#   'fcode': 'GF01030020',
#   'namaobj': 'CANDI ARJUNA',
#   'remark': 'CANDI',
#   'wadmpr': 'JAWA TENGAH',
#   'alamat': 'DIENG KULON, BATUR',
#   'laman': 'https://gis.dukcapil.kemendagri.go.id/'}]

# %%
gdf_kml = gpd.GeoDataFrame(placemark_data, crs=4326)

gdf_kml.head()
# Out:
#                                           id                    geometry  \
# 0  candi_di_jawa_tengah_330020220822074546.1  POINT (110.49583 -7.75436)
# 1  candi_di_jawa_tengah_330020220822074546.2  POINT (110.20382 -7.60796)
# 2  candi_di_jawa_tengah_330020220822074546.3  POINT (110.23012 -7.60482)
# 3  candi_di_jawa_tengah_330020220822074546.4  POINT (110.34182 -7.20813)
# 4  candi_di_jawa_tengah_330020220822074546.5  POINT (110.21956 -7.60613)
#
#   objectid fgsprp       fcode             namaobj remark       wadmpr  \
# 0     3155    999  GF01030020     CANDI PRAMBANAN  CANDI  JAWA TENGAH
# 1      859    999  GF01030020     CANDI BOROBUDUR  CANDI  JAWA TENGAH
# 2     7605    999  GF01030020        CANDI MENDUT  CANDI  JAWA TENGAH
# 3     7606    999  GF01030020  CANDI GEDONG SONGO  CANDI  JAWA TENGAH
# 4     7607    999  GF01030020         CANDI PAWON  CANDI  JAWA TENGAH
#
#                                         alamat  \
# 0  JL. RAYA SOLO - YOGYAKARTA NO. 16 PRAMBANAN
# 1            JL. BADRAWATI, KW CANDI BOROBUDUR
# 2                     JL. MAYOR KUSEN, MUNGKID
# 3       JALAN KE CANDI GEDONG SONGO, BANDUNGAN
# 4                        BROJONALAN, BOROBUDUR
#
#                                     laman
# 0  https://gis.dukcapil.kemendagri.go.id/
# 1  https://gis.dukcapil.kemendagri.go.id/
# 2  https://gis.dukcapil.kemendagri.go.id/
# 3  https://gis.dukcapil.kemendagri.go.id/
# 4  https://gis.dukcapil.kemendagri.go.id/

# %%
gdf_kml.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
